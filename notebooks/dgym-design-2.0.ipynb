# %% [markdown]
# # Create new library designer function

# %% [markdown]
# Import data.

# %%
# %reload_ext autoreload
# %autoreload 2

import rdkit
rdkit.Chem.Draw.IPythonConsole.ipython_maxProperties = -1

import dgym as dg

# load all data
print('load data')
path = '../../dgym-data'

deck = dg.MoleculeCollection.load(
    f'{path}/DSi-Poised_Library_annotated.sdf',
    reactant_names=['reagsmi1', 'reagsmi2', 'reagsmi3']
)

reactions = dg.ReactionCollection.from_json(
    path = f'{path}/All_Rxns_rxn_library.json',
    smarts_col = 'reaction_string',
    classes_col = 'functional_groups'
)
# Out:
# load data

# %%
building_blocks = dg.datasets.disk_loader(f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630.sdf')
fingerprints = dg.datasets.fingerprints(f'{path}/out/Enamine_Building_Blocks_Stock_262336cmpd_20230630.fpb')

# align fingerprints to building blocks
print('align fingerprints')
fingerprints = dg.utils.sort_fingerprints(fingerprints, building_blocks)
# Out:
# align fingerprints

# %% [markdown]
# Create inputs to the DrugEnv.

# %%
import numpy as np
from dgym.envs.library_designer import LibraryDesigner
from dgym.envs.oracle import DGLOracle, RDKitOracle, DockingOracle
from dgym.envs.evaluator import ClassicEvaluator, UtilityFunction

# create library designer
library_designer = LibraryDesigner(
    reactions,
    building_blocks,
    fingerprints
)

# %% [markdown]
# Testing the best performing molecule from docking screen.

# %%
# %%time
mol = dg.molecule.Molecule(
    'Cc1ccccc1C(=O)Nc1nc(-c2cccc(O)c2)cs1',
    reactants = [
        dg.molecule.Molecule('Cc1ccccc1C(=O)O'),
        dg.molecule.Molecule('Nc1nc(-c2cccc(O)c2)cs1'),
    ]
)

library_designer.reset_cache()

analogs = library_designer.design(
    molecule = deck[0],
    num_analogs = 20,
    temperature = 0.0
)
# [display(a) for a in analogs]
# Out:
# CPU times: user 104 ms, sys: 239 µs, total: 104 ms
# Wall time: 103 ms

# %%
import numpy as np
from dgym.envs.library_designer import LibraryDesigner
from dgym.envs.oracle import DGLOracle, RDKitOracle, DockingOracle
from dgym.envs.evaluator import ClassicEvaluator, UtilityFunction

# create library designer
library_designer = LibraryDesigner(
    reactions,
    building_blocks,
    fingerprints
)

# create docking oracle
config = {
    'center_x': 9.812,
    'center_y': -0.257,
    'center_z': 20.8485,
    'size_x': 14.328,
    'size_y': 8.85,
    'size_z': 12.539,
    'exhaustiveness': 128,
    'max_step': 20,
    'num_modes': 9,
    'scoring': 'vinardo',
    'refine_step': 3,
    'seed': 5
}

docking_oracle = DockingOracle(
    'Mpro affinity',
    receptor_path=f'{path}/Mpro_prepped.pdbqt',
    config=config
)

# %%
from tqdm.notebook import tqdm

library_designer.reset_cache()

# best_analog = dg.molecule.Molecule(
#     'Nc1cccc(-c2csc(Nc3ccccc3C(=O)O)n2)c1',
#     reactants = [
#         dg.molecule.Molecule('O=C(O)c1ccccc1Br'),
#         dg.molecule.Molecule('Nc1cccc(-c2csc(N)n2)c1'),
#     ]
# )
# display(best_analog)
# print(5.220108806402527)

# best_analog = dg.molecule.Molecule(
#     'O=C1CCCCc2cc(Oc3cccc(O)c3C(=O)O)ccc21',
#     reactants = [
#         dg.molecule.Molecule('O=C(O)c1c(O)cccc1Cl'),
#         dg.molecule.Molecule('O=C1CCCCc2cc(O)ccc21'),
#     ]
# )
# display(best_analog)
# print(5.753656144113496)


# best_analog = dg.molecule.Molecule(
#     'Nc1ccc(C(=O)c2cc(C(=O)O)c(F)cc2F)cc1C(F)(F)F',
#     reactants = [
#         dg.molecule.Molecule('N#Cc1ccc(N)c(C(F)(F)F)c1'),
#         dg.molecule.Molecule('O=C(O)c1cc(Cl)c(F)cc1F'),
#     ]
# )

# display(best_analog)
# print(4.78480866250603)

# best_analog = dg.molecule.Molecule(
#     'N#CN(C(=O)Cc1ccc2cn[nH]c2c1)c1cccc(C(=O)O)c1',
#     reactants = [
#         dg.molecule.Molecule('O=C(O)Cc1ccc2cn[nH]c2c1'),
#         dg.molecule.Molecule('N#CNc1cccc(C(=O)O)c1'),
#     ]
# )

# display(best_analog)
# print(7.123005139339721)

# best_analog = dg.molecule.Molecule(
#     'O=C(c1ccc2c(c1)CC2)c1cnc(F)c(C(=O)O)c1',
#     reactants = [
#         dg.molecule.Molecule('N#Cc1cnc(F)c(C(=O)O)c1'),
#         dg.molecule.Molecule('Brc1ccc2c(c1)CC2'),
#     ]
# )

# display(best_analog)

# best_analog = dg.molecule.Molecule(
#     'O=C(c1ccc2c(c1)C(=O)CC2)c1cc(C(=O)O)c2ccccc2c1',
#     reactants = [
#         dg.molecule.Molecule('N#Cc1cc(C(=O)O)c2ccccc2c1'),
#         dg.molecule.Molecule('O=C1CCc2ccc(Br)cc21'),
#     ]
# )

# display(best_analog)
# print(5.810801306441787)


best_analog = dg.molecule.Molecule(
    'O=C(c1ccc2c(c1)C(=O)C2)c1cc(C(=O)O)c2ccccc2c1',
    reactants = [
        dg.molecule.Molecule('N#Cc1cc(C(=O)O)c2ccccc2c1'),
        dg.molecule.Molecule('O=C1Cc2ccc(Br)cc21'),
    ]
)

display(best_analog)
print(5.9936139883777475)


# best_analog = dg.molecule.Molecule(
#     'O=C(c1ccc2c(c1)CCCC2)c1ccc(F)c(C(=O)O)c1',
#     reactants = [
#         dg.molecule.Molecule('N#Cc1ccc(F)c(C(=O)O)c1'),
#         dg.molecule.Molecule('Brc1ccc2c(c1)CCCC2'),
#     ]
# )

# display(best_analog)
# print(7.462370863410115)

# best_analog = dg.molecule.Molecule(
#     'O=C(O)c1c(F)ccc(Oc2ccc3c(c2)CCNC3)c1F',
#     reactants = [
#         dg.molecule.Molecule('Brc1ccc2c(c1)CCNC2.Cl'),
#         dg.molecule.Molecule('O=C(O)c1c(F)ccc(O)c1F'),
#     ]
# )

# display(best_analog)
# print(7.66805169179407)

for _ in range(20):

    analogs = library_designer.design(
        molecule = best_analog,
        num_analogs = 100,
        temperature = 0.0
    )

    if analogs:
        
        results = docking_oracle(analogs)
        
        best = np.nanargmax(results).item()
        best_analog = analogs[best]
        best_result = results[best]
        
        display(best_analog)
        print(best_result)
# Out:
# 5.9936139883777475
# 5.9936139883777475
# 5.482826674610165
# 5.701434872199368
# 5.769456816446338
# 5.8092307703263995
# 5.75849330776331
# 5.71842180901497
# 5.383801677698579
# 5.525224079663594
# 5.375682702309252
# 5.333143898263603
# 5.136940037875187
# 5.278128373161649
# 5.388674715118224
# 5.248998436194837
# 5.336594401676636
# 5.340840659909582
# 5.479070321228238
# 5.512480472876578
# 5.803254275266523

# %%
import numpy as np

self = library_designer

# temperature = 2.0
num_analogs = 30
molecule = deck[10]

products = None

# Get analogs of the molecule reactants
# reactants = self._get_analogs(molecule.reactants[0], temperature, num_analogs)
rng = np.random.default_rng()
indices = rng.choice(len(self.building_blocks), size=num_analogs, replace=False)
indices = indices.tolist()
reactants = [self.building_blocks[i] for i in indices]

# Enumerate possible products given repertoire of reactions
products = self._enumerate_products([[molecule.mol], reactants])

# Add inspiration
for product in products:
    product.inspiration = molecule
    
if not len(products) <= num_analogs:
    
    # Sample from product candidates
    products = self._sample_products(products, molecule, temperature, num_analogs)

products
# Out:
# [<dgym.molecule.Molecule at 0x7fafd0ee1090>,
#  <dgym.molecule.Molecule at 0x7fafd0ea64d0>,
#  <dgym.molecule.Molecule at 0x7fafd04b16d0>,
#  <dgym.molecule.Molecule at 0x7fafd0ae0150>,
#  <dgym.molecule.Molecule at 0x7fafd0ab6450>,
#  <dgym.molecule.Molecule at 0x7fafd0f2bc50>,
#  <dgym.molecule.Molecule at 0x7fafd0488150>,
#  <dgym.molecule.Molecule at 0x7fafd080ec50>,
#  <dgym.molecule.Molecule at 0x7fafd04b1f50>,
#  <dgym.molecule.Molecule at 0x7fafd0f2be50>,
#  <dgym.molecule.Molecule at 0x7fafce4622d0>,
#  <dgym.molecule.Molecule at 0x7fafce3bdd50>,
#  <dgym.molecule.Molecule at 0x7fafce388150>,
#  <dgym.molecule.Molecule at 0x7fafd0f3d050>,
#  <dgym.molecule.Molecule at 0x7fafce515890>,
#  <dgym.molecule.Molecule at 0x7fafd0ae31d0>,
#  <dgym.molecule.Molecule at 0x7fafd04b0b90>,
#  <dgym.molecule.Molecule at 0x7fafd0ae0850>,
#  <dgym.molecule.Molecule at 0x7fafd0f32790>,
#  <dgym.molecule.Molecule at 0x7fafd080d890>,
#  <dgym.molecule.Molecule at 0x7fafd080f750>,
#  <dgym.molecule.Molecule at 0x7fafd0ae04d0>,
#  <dgym.molecule.Molecule at 0x7fafce52a050>,
#  <dgym.molecule.Molecule at 0x7fafd0f2a790>,
#  <dgym.molecule.Molecule at 0x7fafd04b04d0>,
#  <dgym.molecule.Molecule at 0x7fafd0f33150>,
#  <dgym.molecule.Molecule at 0x7fafd0ee2010>,
#  <dgym.molecule.Molecule at 0x7fafd0812910>,
#  <dgym.molecule.Molecule at 0x7fafd0ea6390>,
#  <dgym.molecule.Molecule at 0x7fafd0f3c250>]

# %%
[display(p) for p in products]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
