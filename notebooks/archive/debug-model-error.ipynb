# %% [markdown]
# # Debug model error experiment

# %%
import uuid
import argparse
import dgym as dg
import pandas as pd

def get_data(path):

    deck = dg.MoleculeCollection.load(
        f'{path}/DSi-Poised_Library_annotated.sdf',
        reactant_names=['reagsmi1', 'reagsmi2', 'reagsmi3']
    )

    reactions = dg.ReactionCollection.from_json(
        path = f'{path}/All_Rxns_rxn_library_sorted.json',
        smarts_col = 'reaction_string',
        classes_col = 'functional_groups'
    )

    building_blocks = dg.datasets.disk_loader(
        f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630.sdf')
    fingerprints = dg.datasets.fingerprints(
        f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630_atoms.fpb')

    import torch
    import pyarrow.parquet as pq
    table = pq.read_table(f'{path}/sizes.parquet')[0]
    sizes = torch.tensor(table.to_numpy())

    return deck, reactions, building_blocks, fingerprints, sizes

def get_initial_library(deck, designer):
    
    # select first molecule
    import random
    def _select_molecule(deck):
        initial_index = random.randint(0, len(deck) - 1)
        initial_molecule = deck[initial_index]
        if len(initial_molecule.reactants) == 2 \
            and designer.match_reactions(initial_molecule):
            return initial_molecule
        else:
            return _select_molecule(deck)

    initial_molecules = [_select_molecule(deck) for _ in range(5)]
    library = dg.MoleculeCollection(initial_molecules).update_annotations()
    
    return library
    
def get_docking_config(path: str, target_index: int):
    
    import os

    dockstring_dir = f'{path}/dockstring_targets/'
    files = os.listdir(dockstring_dir)
    configs = sorted([f for f in files if 'conf' in f])
    targets = sorted([f for f in files if 'target' in f])

    with open(dockstring_dir + configs[target_index], 'r') as f:
        config_ = f.readlines()
        config_ = [c.replace('\n', '') for c in config_]
        config_ = [c.split(' = ') for c in config_ if c]
        config_ = {c[0]: float(c[1]) for c in config_}

    target_file = targets[target_index]
    target = target_file.split('_')[0]
    
    config = {
        'search_mode': 'detailed',
        'scoring': 'vina',
        'seed': 5,
        'size_x': 22.5,
        'size_y': 22.5,
        'size_z': 22.5,
        **config_
    }
    
    return target, config

def get_oracles(path: str, target_index: int):

    from dgym.envs.oracle import \
        DockingOracle, CatBoostOracle, RDKitOracle, NoisyOracle
    from dgym.envs.utility import ClassicUtilityFunction
    
    target, config = get_docking_config(path, target_index)

    pIC50_oracle = DockingOracle(
        f'{target} pIC50',
        receptor_path=f'{path}/dockstring_targets/{target}_target.pdbqt',
        config=config
    )
    log_P_oracle = RDKitOracle('Log P', descriptor='MolLogP')
    log_S_oracle = CatBoostOracle(
        'Log S', path='../dgym/envs/models/aqsolcb.model')
    
    return pIC50_oracle, log_P_oracle, log_S_oracle

def get_multiple_utility_functions(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle,
    sigma=1.0
):
    from dgym.envs.utility import (
        ClassicUtilityFunction, MultipleUtilityFunction
    )

    # Define utility functions
    pIC50_utility = ClassicUtilityFunction(
        pIC50_oracle, ideal=(9, 13), acceptable=(8, 13))
    log_P_utility = ClassicUtilityFunction(
        log_P_oracle, ideal=(0.5, 1.85), acceptable=(-0.5, 3.5))
    log_S_utility = ClassicUtilityFunction(
        log_S_oracle, ideal=(-3, 1), acceptable=(-4, 1))

    # Assemble assays and surrogate models
    assays = [
        pIC50_oracle,
        log_P_oracle,
        log_S_oracle,
        pIC50_oracle.surrogate(sigma=sigma),
        log_P_oracle.surrogate(sigma=sigma),
        log_S_oracle.surrogate(sigma=sigma),
    ]

    # Environment tolerates acceptable ADMET
    from copy import deepcopy
    utility_agent = MultipleUtilityFunction(
        utility_functions = [pIC50_utility, log_P_utility, log_S_utility],
        weights = [0.8, 0.1, 0.1]
    )
    utility_env = deepcopy(utility_agent)
    utility_env.utility_functions[1].ideal = utility_env.utility_functions[1].acceptable
    utility_env.utility_functions[2].ideal = utility_env.utility_functions[2].acceptable
    
    return assays, utility_agent, utility_env

def get_agent_sequence(batch_size: int = 8, score_ratio: int = 5):
    """
    Make the sequence for the DrugAgent.
    """
    design_size_1 = max(score_ratio // 2, 1)
    design_size_2 = max(score_ratio - design_size_1, 1)
    design_replace = {
        'name': 'design',
        'batch_size': batch_size,
        'parameters': {'strategy': 'replace', 'size': design_size_1, 'temperature': 0.16, 'limit': 1}
    }
    design_grow = {
        'name': 'design',
        'batch_size': batch_size,
        'parameters': {'strategy': 'grow', 'size': design_size_2}
    }
    score = {
        'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'],
        'batch_size': batch_size * score_ratio,
        'parameters': {'parallel': False, 'batch_size': 40}
    }
    make = {'name': 'make', 'batch_size': batch_size}
    test = {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'batch_size': batch_size}

    return [design_replace, score, design_grow, score, make, test]

# %%
# Run experiment
sigma = 2.0
path = '../../dgym-data'

# Load all data
(
    deck,
    reactions,
    building_blocks,
    fingerprints,
    sizes
) = get_data(path)

# Get starting library
from dgym.envs.designer import Designer, Generator
designer = Designer(
    Generator(building_blocks, fingerprints, sizes), reactions, cache = True)
library = get_initial_library(deck, designer)

# Get Oracles
(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle
) = get_oracles(
    path=path,
    target_index=0
)

# Create multiple utility functions
(
    assays,
    utility_agent,
    utility_env
) = get_multiple_utility_functions(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle,
    sigma=sigma
)

# Create DrugEnv
from dgym.envs import DrugEnv
drug_env = DrugEnv(
    designer = designer,
    library = library,
    assays = assays,
    utility_function = utility_env
)

from dgym.agents import SequentialDrugAgent
from dgym.agents.exploration import EpsilonGreedy
sequence = get_agent_sequence(score_ratio = 10)
drug_agent = SequentialDrugAgent(
    sequence = sequence,
    exploration_strategy = EpsilonGreedy(epsilon=0.2),
    utility_function = utility_agent
)

# Create and run Experiment
# file_path = f'./out/selection_temperature_{temperature}_{uuid.uuid4()}.json'

from dgym.experiment import Experiment
experiment = Experiment(
    drug_agent=drug_agent, drug_env=drug_env)
result = experiment.run(sigma=sigma)[0]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Memory before action: Memory Usage: 7.85 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.16, 'limit': 1}, 'molecules': [0, 1, 2, 3, 4]}
# Memory after action: Memory Usage: 7.90 GB
# -inf
# Memory before action: Memory Usage: 7.90 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'parallel': False, 'batch_size': 40}, 'molecules': [6, 23, 5, 7, 26, 20, 8, 9, 10, 16, 11, 12, 13, 14, 15, 17, 28, 18, 19, 21, 22, 24, 25, 27, 29]}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# Memory after action: Memory Usage: 7.89 GB
# -inf
# Memory before action: Memory Usage: 7.89 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [16, 13, 6, 25, 23, 10, 7, 27]}
# Memory after action: Memory Usage: 7.89 GB
# -inf
# Memory before action: Memory Usage: 7.89 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'parallel': False, 'batch_size': 40}, 'molecules': [30, 31, 33, 32, 34, 35, 46, 36, 37, 38, 63, 39, 61, 40, 41, 42, 50, 43, 44, 45, 53, 47, 48, 49, 51, 52, 54, 55, 56, 57, 58, 64, 59, 60, 62]}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# Memory after action: Memory Usage: 7.90 GB
# -inf
# Memory before action: Memory Usage: 7.90 GB
# Created action
# {'name': 'make', 'parameters': {}, 'molecules': [32, 30, 55, 16, 13, 31, 25, 57]}
# Memory after action: Memory Usage: 7.90 GB
# -inf
# Memory before action: Memory Usage: 7.89 GB
# Created action
# {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'parameters': {}, 'molecules': [55, 16, 13, 25, 57, 31, 30, 32]}
# {}
# {}
# {}
# Memory after action: Memory Usage: 7.89 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 7.89 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.16, 'limit': 1}, 'molecules': [10, 7, 50, 56, 64, 16, 30, 13]}
# Memory after action: Memory Usage: 7.96 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 7.96 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'parallel': False, 'batch_size': 40}, 'molecules': [65, 66, 67, 68, 103, 69, 70, 79, 71, 87, 72, 73, 74, 75, 76, 77, 78, 80, 81, 82, 90, 85, 83, 84, 86, 88, 89, 91, 92, 93, 101, 94, 95, 96, 97, 98, 99, 100, 104, 102]}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# Memory after action: Memory Usage: 7.97 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 7.97 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [87, 98, 66, 10, 7, 50, 56, 64]}
# Memory after action: Memory Usage: 7.97 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 7.97 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'parallel': False, 'batch_size': 40}, 'molecules': [105, 106, 107, 132, 108, 109, 110, 111, 112, 131, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 130, 127, 128, 134, 129, 133]}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# Memory after action: Memory Usage: 7.97 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 7.97 GB
# Created action
# {'name': 'make', 'parameters': {}, 'molecules': [110, 87, 98, 12, 115, 66, 125, 116]}
# Memory after action: Memory Usage: 7.97 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 7.97 GB
# Created action
# {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'parameters': {}, 'molecules': [110, 87, 98, 115, 66, 125, 116, 12]}
# {}
# {}
# {}
# Memory after action: Memory Usage: 7.97 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 7.97 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.16, 'limit': 1}, 'molecules': [57, 132, 32, 31, 106, 16, 64, 70]}
# Memory after action: Memory Usage: 8.05 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 8.05 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'parallel': False, 'batch_size': 40}, 'molecules': [135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 155, 145, 174, 146, 147, 148, 149, 150, 151, 157, 152, 153, 154, 156, 159, 158, 168, 167, 170, 160, 161, 162, 163, 173, 164, 165, 166, 169, 171, 172]}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# {'parallel': False, 'batch_size': 40}
# Memory after action: Memory Usage: 8.06 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 8.06 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [57, 32, 31, 144, 16, 154, 159, 160]}
# Memory after action: Memory Usage: 8.06 GB
# -0.3071918931057914
# Memory before action: Memory Usage: 8.06 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'parallel': False, 'batch_size': 40}, 'molecules': [175, 176, 197, 181, 177, 178, 190, 179, 204, 180, 182, 183, 184, 186, 185, 187, 188, 189, 191, 192, 193, 194, 195, 203, 196, 198, 199, 200, 201, 202]}
# {'parallel': False, 'batch_size': 40}
# KeyboardInterrupt
