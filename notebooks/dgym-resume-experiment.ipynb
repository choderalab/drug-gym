# %% [markdown]
# # Testing New Experiment API

# %% [markdown]
# Load data.

# %%
# %reload_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore') 

import rdkit
import dgym as dg

# load all data
path = '../../dgym-data'

deck = dg.MoleculeCollection.load(
    f'{path}/DSi-Poised_Library_annotated.sdf',
    reactant_names=['reagsmi1', 'reagsmi2', 'reagsmi3']
)

reactions = dg.ReactionCollection.from_json(
    path = f'{path}/All_Rxns_rxn_library_sorted.json',
    smarts_col = 'reaction_string',
    classes_col = 'functional_groups'
)

building_blocks = dg.datasets.disk_loader(f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630.sdf')
fingerprints = dg.datasets.fingerprints(f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630_atoms.fpb')

import torch
import pyarrow.parquet as pq
table = pq.read_table('../../dgym-data/sizes.parquet')[0]
sizes = torch.tensor(table.to_numpy())

# %% [markdown]
# Load assays and utility functions.

# %%
import os

def get_tcp_objectives():

    dockstring_dir = f'{path}/dockstring_targets/'
    files = os.listdir(dockstring_dir)
    configs = sorted([f for f in files if 'conf' in f])
    targets = sorted([f for f in files if 'target' in f])

    idx = 0
    with open(dockstring_dir + configs[idx], 'r') as f:
        config_ = f.readlines()
        config_ = [c.replace('\n', '') for c in config_]
        config_ = [c.split(' = ') for c in config_ if c]
        config_ = {c[0]: float(c[1]) for c in config_}

    target = targets[idx]
    name = target.split('_')[0]

    config_.update({
        'size_x': 22.5,
        'size_y': 22.5,
        'size_z': 22.5,
    })

    from dgym.envs.oracle import \
        DockingOracle, CatBoostOracle, RDKitOracle, NoisyOracle
    from dgym.envs.utility import ClassicUtilityFunction

    config = {
        'search_mode': 'detailed',
        'scoring': 'vina',
        'seed': 5,
        **config_
    }

    pIC50_oracle = DockingOracle(
        f'{name} pIC50',
        receptor_path=f'{path}/dockstring_targets/{name}_target.pdbqt',
        config=config
    )
    qed_oracle = RDKitOracle('QED', descriptor='QED')
    log_P_oracle = RDKitOracle('Log P', descriptor='MolLogP')
    log_S_oracle = CatBoostOracle(
        'Log S', path='../dgym/envs/models/aqsolcb.model')
    
    return pIC50_oracle, qed_oracle, log_P_oracle, log_S_oracle

# %%
from dgym.envs.utility import ClassicUtilityFunction, MultipleUtilityFunction

# Get objectives
pIC50_oracle, qed_oracle, log_P_oracle, log_S_oracle = get_tcp_objectives()

# Define utility functions
pIC50_utility = ClassicUtilityFunction(
    pIC50_oracle, ideal=(9.5, 13), acceptable=(8, 13))
log_P_utility = ClassicUtilityFunction(
    log_P_oracle, ideal=(0.5, 1.85), acceptable=(-0.5, 3.5))
log_S_utility = ClassicUtilityFunction(
    log_S_oracle, ideal=(-3, 1), acceptable=(-4, 1))
# qed_utility = ClassicUtilityFunction(
#     qed_oracle, ideal=(0.65, 1.0), acceptable=(0.5, 1.0))

# Assemble assays and surrogate models
assays = [
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle,
    # qed_oracle,
    pIC50_oracle.surrogate(sigma=1.0),
    log_P_oracle.surrogate(sigma=1.0),
    log_S_oracle.surrogate(sigma=1.0),
    # qed_oracle.surrogate(sigma=0.1),
]

# Environment tolerates acceptable ADMET
from copy import deepcopy
utility_agent = MultipleUtilityFunction(
    utility_functions = [pIC50_utility, log_P_utility, log_S_utility],
    weights = [0.8, 0.1, 0.1]
)
utility_env = deepcopy(utility_agent)
utility_env.utility_functions[1].ideal = utility_env.utility_functions[1].acceptable
utility_env.utility_functions[2].ideal = utility_env.utility_functions[2].acceptable

# %% [markdown]
# Instantiate designer.

# %%
from dgym.envs.designer import Designer, Generator

designer = Designer(
    Generator(building_blocks, fingerprints, sizes),
    reactions,
    cache = True
)

# %% [markdown]
# Pick 5 random starting hits.

# %%
# select first molecule
import random
def select_molecule(deck):
    initial_index = random.randint(0, len(deck) - 1)
    initial_molecule = deck[initial_index]
    if len(initial_molecule.reactants) == 2 \
        and designer.match_reactions(initial_molecule):
        return initial_molecule
    else:
        return select_molecule(deck)

initial_molecules = [select_molecule(deck) for _ in range(5)]
library = dg.MoleculeCollection(initial_molecules).update_annotations()

# Score molecules
for assay in assays:
    if 'Noisy' not in assay.name:
        results = assay(library)
        for molecule, result in zip(library, results):
            molecule.update_annotations({assay.name: result})

# Set status to tested
library.set_status('Tested', step=0)
# Out:
# Step Tested 0
# Step Tested 0
# Step Tested 0
# Step Tested 0
# Step Tested 0

# %% [markdown]
# Instantiate Environment and Agent.

# %%
from dgym.envs import DrugEnv
from dgym.agents import SequentialDrugAgent
from dgym.agents.exploration import EpsilonGreedy

drug_env = DrugEnv(
    designer = designer,
    library = library,
    assays = assays,
    utility_function = utility_env
)

# Construct sequence
design_grow = {'name': 'design', 'batch_size': 8, 'parameters': {'strategy': 'grow', 'size': 5}}
design_replace = {'name': 'design', 'batch_size': 8, 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}}
score = {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'batch_size': 8 * 5, 'parameters': {'batch_size': 40}}
make = {'name': 'make', 'batch_size': 8}
test = {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'batch_size': 8}
sequence = [design_replace, score, design_grow, score, make, test]

drug_agent = SequentialDrugAgent(
    sequence = sequence,
    exploration_strategy = EpsilonGreedy(epsilon=0.25),
    utility_function = utility_agent
)

# %%
def display_best(experiment):
    import numpy as np
    observations = experiment.drug_env.library
    utilities = experiment.drug_env.utility_function(
        observations, use_precomputed=True, method='average')
    for obs, utility in zip(observations, utilities):
        obs.update_annotations({'utility': utility})
    tested = observations.tested
    if tested:
        best_tested = (
            tested
            .annotations
            .sort_values('utility', ascending=False)
            [['ABL1 pIC50', 'Log S', 'Log P', 'utility']]
            .head()
        )
        display(best_tested)

# %%
from dgym.experiment import Experiment

experiment = Experiment(
    drug_env=drug_env,
    drug_agent=drug_agent
)

result = experiment.run()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Memory before action: Memory Usage: 6.29 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}, 'molecules': [0, 4, 2, 3, 1]}
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Memory after action: Memory Usage: 6.44 GB
# -1.1826376364908393
# Memory before action: Memory Usage: 6.45 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [5, 6, 7, 8, 9, 10, 21, 11, 24, 12, 28, 13, 20, 14, 15, 16, 17, 18, 19, 22, 23, 25, 29, 26, 27]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Memory after action: Memory Usage: 6.41 GB
# -1.1826376364908393
# Memory before action: Memory Usage: 6.40 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [12, 19, 7, 27, 5, 26, 15, 25]}
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Memory after action: Memory Usage: 6.36 GB
# -1.1826376364908393
# Memory before action: Memory Usage: 6.36 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [30, 31, 58, 32, 48, 33, 34, 35, 36, 37, 50, 38, 39, 40, 51, 41, 44, 55, 45, 59, 42, 43, 46, 57, 47, 49, 64, 63, 52, 53, 54, 56, 60, 61, 62]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Step Scored 0
# Memory after action: Memory Usage: 6.41 GB
# -1.1826376364908393
# Memory before action: Memory Usage: 6.37 GB
# Created action
# {'name': 'make', 'parameters': {}, 'molecules': [36, 12, 33, 7, 27, 5, 26, 24]}
# Step Made 1
# Step Made 1
# Step Made 1
# Step Made 1
# Step Made 1
# Step Made 1
# Step Made 1
# Step Made 1
# Memory after action: Memory Usage: 6.37 GB
# -1.1826376364908393
# Memory before action: Memory Usage: 6.37 GB
# Created action
# {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'parameters': {}, 'molecules': [12, 7, 27, 5, 36, 26, 33, 24]}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# Step Tested 1
# Step Tested 1
# Step Tested 1
# Step Tested 1
# Step Tested 1
# Step Tested 1
# Step Tested 1
# Step Tested 1
# Memory after action: Memory Usage: 6.38 GB
# -0.15232570792132674
# Memory before action: Memory Usage: 6.37 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}, 'molecules': [5, 17, 0, 15, 42, 30, 26, 47]}
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Memory after action: Memory Usage: 6.47 GB
# -0.15232570792132674
# Memory before action: Memory Usage: 6.47 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [69, 65, 66, 67, 68, 101, 70, 71, 72, 75, 73, 96, 74, 76, 77, 88, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 89, 91, 99, 103, 90, 92, 93, 100, 94, 95, 97, 98, 102, 104]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Memory after action: Memory Usage: 6.52 GB
# -0.15232570792132674
# Memory before action: Memory Usage: 6.47 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [5, 8, 0, 15, 30, 84, 26, 78]}
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Step Designed 1
# Memory after action: Memory Usage: 6.47 GB
# -0.15232570792132674
# Memory before action: Memory Usage: 6.47 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [85, 105, 106, 107, 108, 133, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 129, 124, 125, 126, 132, 127, 128, 131, 130, 134]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Step Scored 1
# Memory after action: Memory Usage: 6.52 GB
# -0.15232570792132674
# Memory before action: Memory Usage: 6.48 GB
# Created action
# {'name': 'make', 'parameters': {}, 'molecules': [84, 118, 15, 100, 30, 80, 88, 68]}
# Step Made 2
# Step Made 2
# Step Made 2
# Step Made 2
# Step Made 2
# Step Made 2
# Step Made 2
# Step Made 2
# Memory after action: Memory Usage: 6.48 GB
# -0.15232570792132674
# Memory before action: Memory Usage: 6.47 GB
# Created action
# {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'parameters': {}, 'molecules': [84, 88, 68, 118, 15, 30, 80, 100]}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# Step Tested 2
# Step Tested 2
# Step Tested 2
# Step Tested 2
# Step Tested 2
# Step Tested 2
# Step Tested 2
# Step Tested 2
# Memory after action: Memory Usage: 6.47 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.47 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}, 'molecules': [84, 80, 5, 0, 15, 115, 68, 54]}
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Memory after action: Memory Usage: 6.54 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.54 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [85, 135, 136, 137, 138, 160, 139, 140, 141, 174, 142, 143, 170, 154, 168, 144, 169, 171, 163, 145, 146, 162, 147, 148, 149, 150, 151, 152, 153, 155, 156, 157, 158, 159, 167, 161, 164, 165, 172, 166]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Memory after action: Memory Usage: 6.58 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.54 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [84, 80, 5, 168, 125, 108, 0, 171]}
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Step Designed 2
# Memory after action: Memory Usage: 6.54 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.54 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [181, 190, 85, 173, 175, 176, 177, 178, 179, 180, 182, 183, 184, 194, 185, 192, 186, 187, 188, 189, 191, 193]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Step Scored 2
# Memory after action: Memory Usage: 6.58 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.54 GB
# Created action
# {'name': 'make', 'parameters': {}, 'molecules': [168, 135, 180, 139, 155, 166, 158, 177]}
# Step Made 3
# Step Made 3
# Step Made 3
# Step Made 3
# Step Made 3
# Step Made 3
# Step Made 3
# Step Made 3
# Memory after action: Memory Usage: 6.54 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.54 GB
# Created action
# {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'parameters': {}, 'molecules': [168, 155, 180, 139, 158, 135, 177, 166]}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# Step Tested 3
# Step Tested 3
# Step Tested 3
# Step Tested 3
# Step Tested 3
# Step Tested 3
# Step Tested 3
# Step Tested 3
# Memory after action: Memory Usage: 6.54 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.54 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}, 'molecules': [139, 145, 84, 80, 5, 155, 168, 0]}
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Memory after action: Memory Usage: 6.60 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.60 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [85, 195, 196, 208, 203, 219, 197, 227, 198, 199, 200, 231, 201, 233, 223, 202, 210, 204, 205, 211, 217, 206, 207, 214, 209, 212, 213, 215, 216, 230, 222, 226, 218, 220, 229, 221, 224, 225, 228, 234]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Memory after action: Memory Usage: 6.64 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.60 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [139, 84, 80, 5, 155, 150, 168, 0]}
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Step Designed 3
# Memory after action: Memory Usage: 6.60 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.60 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [85, 251, 232, 235, 236, 258, 249, 255, 237, 243, 238, 239, 240, 263, 241, 242, 244, 245, 246, 261, 247, 248, 256, 250, 257, 264, 252, 253, 254, 259, 260, 262]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Step Scored 3
# Memory after action: Memory Usage: 6.65 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.60 GB
# Created action
# {'name': 'make', 'parameters': {}, 'molecules': [234, 220, 226, 165, 259, 78, 211, 48]}
# Step Made 4
# Step Made 4
# Step Made 4
# Step Made 4
# Step Made 4
# Step Made 4
# Step Made 4
# Step Made 4
# Memory after action: Memory Usage: 6.60 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.60 GB
# Created action
# {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'parameters': {}, 'molecules': [234, 220, 226, 78, 165, 48, 259, 211]}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# ['Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made', 'Made']
# {}
# Step Tested 4
# Step Tested 4
# Step Tested 4
# Step Tested 4
# Step Tested 4
# Step Tested 4
# Step Tested 4
# Step Tested 4
# Memory after action: Memory Usage: 6.60 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.60 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}, 'molecules': [139, 84, 80, 171, 220, 5, 155, 226]}
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Memory after action: Memory Usage: 6.65 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.65 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [85, 265, 266, 277, 267, 268, 269, 270, 271, 272, 273, 284, 298, 274, 275, 276, 278, 279, 292, 280, 281, 282, 299, 295, 289, 283, 285, 286, 294, 287, 288, 301, 290, 291, 293, 303, 300, 296, 297, 304]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Step Scored 4
# Memory after action: Memory Usage: 6.70 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.65 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [139, 84, 80, 220, 5, 155, 154, 295]}
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Step Designed 4
# Memory after action: Memory Usage: 6.65 GB
# 0.05875581963143359
# Memory before action: Memory Usage: 6.65 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [85, 302, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 330, 316, 317, 318, 328, 332, 319, 320, 321, 322, 323, 324, 326, 325, 331, 327, 329, 333, 334]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# KeyboardInterrupt

# %% [markdown]
# ## Restore old experiment

# %%
result = new_experiment.get_result(1)

# %%
import ast
import pandas as pd

def load(result):
    annotations = pd.DataFrame(result['annotations'])
    molecules = []
    for idx, annotation in annotations.iterrows():

        # Parse data structure
        annotation = annotation.to_dict()
        route = annotation.pop('Synthetic Route')
        try:
            route = ast.literal_eval(route)
        except:
            pass
        route['annotations'] = annotation

        # Load molecule
        molecule = dg.molecule.Molecule.load(route)

        # Append to library
        molecules.append(molecule)

    collection = dg.collection.MoleculeCollection(molecules)

# %%
from dgym.envs import DrugEnv
from dgym.agents import SequentialDrugAgent
from dgym.agents.exploration import EpsilonGreedy

new_drug_env = DrugEnv(
    designer = designer,
    library = collection,
    assays = assays,
    utility_function = utility_env
)

# Construct sequence
design_grow = {'name': 'design', 'batch_size': 8, 'parameters': {'strategy': 'grow', 'size': 5}}
design_replace = {'name': 'design', 'batch_size': 8, 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}}
score = {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'batch_size': 8 * 5, 'parameters': {'batch_size': 40}}
make = {'name': 'make', 'batch_size': 8}
test = {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'batch_size': 8}
sequence = [design_replace, score, design_grow, score, make, test]

drug_agent = SequentialDrugAgent(
    sequence = sequence,
    exploration_strategy = EpsilonGreedy(epsilon=0.25),
    utility_function = utility_agent
)

# %%
from dgym.experiment import Experiment

new_experiment = Experiment(
    drug_env=new_drug_env,
    drug_agent=drug_agent
)

result = new_experiment.run()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Memory before action: Memory Usage: 6.90 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.2}, 'molecules': [367, 139, 220, 5, 155, 226, 325, 168]}
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Step Designed 0
# Memory after action: Memory Usage: 6.92 GB
# 0.28970253030851006
# Memory before action: Memory Usage: 6.92 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40}, 'molecules': [85, 377, 379, 380, 383, 428, 472, 384, 446, 385, 437, 386, 478, 387, 461, 388, 389, 390, 391, 392, 451, 393, 394, 395, 396, 397, 452, 416, 398, 399, 400, 401, 414, 404, 405, 406, 407, 424, 408, 460]}
# ['Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed', 'Designed']
# {'batch_size': 40}
# Exception ignored in: <function WeakSet.__init__.<locals>._remove at 0x7f11a71a0040>
# Traceback (most recent call last):
#   File "/home/mrr/miniconda3/envs/chodera/lib/python3.11/_weakrefset.py", line 39, in _remove
#     def _remove(item, selfref=ref(self)):
#
# KeyboardInterrupt:
#
# KeyboardInterrupt
