# %% [markdown]
# # Implementing ability to load old experiments

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import json
import zipfile
import pandas as pd
from tqdm.auto import tqdm
from io import TextIOWrapper
from collections import defaultdict

# %%
def get_records(path, measure):

    trial_indices = defaultdict(int)
    
    with zipfile.ZipFile(path, 'r') as z:
        for filename in tqdm(z.namelist()[:1]):
            if filename.endswith('.json'):
                with z.open(filename) as file:
                    with TextIOWrapper(file, encoding='utf-8') as text_file:
                        try:
                            result = json.load(text_file)
                            record = pd.DataFrame(
                                result['annotations']
                            )
                            value = result[measure]
                            trial_indices[value] += 1
                            record[measure] = value
                            record['trial'] = trial_indices[value]
                            
                            records.append(record)
                            result = None
                        except:
                            continue
    return records

paths = [
    '../../dgym-data/analysis/batch_size/selection_batch_2024-05-08_21-49-53.zip',
]

measure = 'batch_size'
records = []
for path in paths:
    records.extend(get_records(path, measure))

df_raw = pd.concat(records)
records = None
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_raw
# Out:
#                                                  SMILES  \
# 0                           CN(C)C(=O)c1cc(C2CC2)[nH]n1
# 1                                       CNCc1cccc(OC)n1
# 2                                Cc1cc(N2CCNCC2)nc(C)n1
# 3                                       CC(O)CNC1CCCCC1
# 4                      Cn1ccc(C(=O)Nc2cccc(C(=O)O)c2)n1
# ...                                                 ...
# 1563  CC(CC(=O)N(C(=NO)C1CCCO1)c1ccc(-n2nc(C(=O)N3CC...
# 1564  NS(=O)(=O)CC(=O)N(C(=NO)C1CCCO1)c1ccc(-n2nc(C(...
# 1565  CC(C)(N)C(=O)N(C(=NO)C1CCCO1)c1ccc(-n2nc(C(=O)...
# 1566  O=C(c1cc(C2CC2)n(-c2ccc(N(C(=O)C3CC(Br)(Br)C3)...
# 1567  CC(C)(O)[C@@H](N)C(=O)N(C(=NO)C1CCCO1)c1ccc(-n...
#
#                                               Reactants  Step Designed  \
# 0                     [CNC.Cl, O=C(O)c1cc(C2CC2)[nH]n1]            NaN
# 1                                 [CN, COc1cccc(C=O)n1]            NaN
# 2            [CC(C)(C)OC(=O)N1CCNCC1, Cc1cc(Cl)nc(C)n1]            NaN
# 3                                 [CC(O)CN, O=C1CCCCC1]            NaN
# 4                [COC(=O)c1cccc(N)c1, Cn1ccc(C(=O)O)n1]            NaN
# ...                                                 ...            ...
# 1563  ['O=C(c1cc(C2CC2)n(-c2ccc(NC(=NO)C3CCCO3)cn2)n...           14.0
# 1564  ['O=C(c1cc(C2CC2)n(-c2ccc(NC(=NO)C3CCCO3)cn2)n...           14.0
# 1565  ['O=C(c1cc(C2CC2)n(-c2ccc(NC(=NO)C3CCCO3)cn2)n...           14.0
# 1566  ['O=C(c1cc(C2CC2)n(-c2ccc(NC(=NO)C3CCCO3)cn2)n...           14.0
# 1567  ['O=C(c1cc(C2CC2)n(-c2ccc(NC(=NO)C3CCCO3)cn2)n...           14.0
#
#       Step Scored  Step Made  Step Tested Current Status  ABL1 pIC50  Log P  \
# 0             NaN        NaN          NaN           None         NaN    NaN
# 1             NaN        NaN          NaN           None         NaN    NaN
# 2             NaN        NaN          NaN           None         NaN    NaN
# 3             NaN        NaN          NaN           None         NaN    NaN
# 4             NaN        NaN          NaN           None         NaN    NaN
# ...           ...        ...          ...            ...         ...    ...
# 1563         14.0        NaN          NaN         Scored         NaN    NaN
# 1564         14.0        NaN          NaN         Scored         NaN    NaN
# 1565         14.0        NaN          NaN         Scored         NaN    NaN
# 1566         14.0        NaN          NaN         Scored         NaN    NaN
# 1567         14.0        NaN          NaN         Scored         NaN    NaN
#
#       Log S  Noisy ABL1 pIC50  Noisy Log P  Noisy Log S  batch_size  trial
# 0       NaN               NaN          NaN          NaN          12      1
# 1       NaN               NaN          NaN          NaN          12      1
# 2       NaN               NaN          NaN          NaN          12      1
# 3       NaN               NaN          NaN          NaN          12      1
# 4       NaN               NaN          NaN          NaN          12      1
# ...     ...               ...          ...          ...         ...    ...
# 1563    NaN          4.473164     2.268408    -3.797957          12      1
# 1564    NaN          5.067532     0.256102    -3.603758          12      1
# 1565    NaN          8.207389     1.781039    -4.950335          12      1
# 1566    NaN          7.695617     3.462841    -6.038497          12      1
# 1567    NaN          7.699356     1.678276    -3.290851          12      1
#
# [3136 rows x 15 columns]
