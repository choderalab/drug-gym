# %%
import pandas as pd

affinity = pd.read_csv('../../dgym-data/out/strict_fragments_array.tsv', sep='\t')

# %%
import seaborn as sns

sns.displot(
    affinity['affinity'].dropna().astype(float)
)
# Out:
# /home/mrr/miniconda3/envs/chodera/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
affinity['affinity'].dropna().astype(float).sort_values().head(1_000)
# Out:
# 370281   -6.577473
# 380310   -6.542908
# 742448   -6.532256
# 222292   -6.501077
# 239711   -6.474622
#             ...
# 146999   -6.022832
# 729809   -6.022588
# 514151   -6.022551
# 26857    -6.022365
# 367597   -6.022351
# Name: affinity, Length: 1000, dtype: float64

# %%
affinity.iloc[370281]
# Out:
# smiles      O=C1CCC[C@H](C(=O)Nc2ccccc2)N1
# affinity                         -6.577473
# Name: 370281, dtype: object
