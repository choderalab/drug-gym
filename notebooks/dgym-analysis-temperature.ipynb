# %% [markdown]
# Imports.

# %%
# %reload_ext autoreload
# %autoreload 2

import rdkit
rdkit.Chem.Draw.IPythonConsole.ipython_maxProperties = -1

import os
import numpy as np
import dgym as dg
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Opening experimental results.

# %%
path = '../../dgym-data/analysis/temperature/new/'
files = os.listdir(path)

results = []
for file in files:
    if file.endswith('json'):
        result = json.load(open(path + file, 'r'))
        results.append(result[0])

df = pd.DataFrame(results)

# %% [markdown]
# Convert to ECDF.

# %%
def ecdf(costs):
    n_trials = len(costs)
    
    costs_sorted = np.sort(costs)
    costs_sorted = [0.0, *costs_sorted]
    
    n_success = np.arange(1, n_trials + 1)
    n_success = np.array([0, *n_success])
    n_failure = n_trials - n_success
    probs = n_success / n_trials
    
    return costs_sorted, probs, n_success, n_failure

# %%
data = pd.DataFrame()
noises = df['temperature'].unique()
for noise in noises:
    raw_costs = [r['cost'] for r in df.to_dict('records') if r['temperature'] == noise]
    cost, prob, n_success, n_failure = ecdf(raw_costs)
    temp = pd.DataFrame({
        'cost': cost,
        'prob': prob,
        'n_success': n_success,
        'n_failure': n_failure,
        'temperature': noise,
    })
    data = pd.concat([data, temp])

# %% [markdown]
# Compute confidence interval.

# %% [markdown]
# Plot.

# %%
from scipy.stats import beta

def compute_confidence_interval(n_success, n_failure):
    ci = beta.interval(0.95, 1 + n_success, 1 + n_failure)
    return ci

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
g = sns.lineplot(
    data,
    x='cost',
    y='prob',
    hue='temperature',
    palette='colorblind',
    errorbar=None
)

# for name, group in data.groupby('temperature'):

#     lower, upper = compute_confidence_interval(
#         group['n_success'],
#         group['n_failure']
#     )
    
#     g.fill_between(
#         group['cost'],
#         lower,
#         upper,
#         alpha=0.2
#     )

g.set_title('Escalating temperature in IDEATION step')
g.set_xlabel('# Molecules')
g.set_ylabel('Probability of Reaching Goal')
g.set_ylim([0, 1.1])
g.set_xlim(0, 200)
# plt.legend([], frameon=False)

plt.gcf().set_dpi(150)
plt.show()

# %% [markdown]
# Plotting for fixed cost.

# %%
at_cost = 100
at_cost_results = []
for sigma, group in df.groupby('temperature'):
    
    total = len(group)
    n_success = (group['cost'] < at_cost).sum()
    n_failure = total - n_success
    prob = n_success / total
    
    at_cost_results.append(
        {
            'temperature': sigma,
            'prob': prob,
            'n_success': n_success,
            'n_failure': n_failure
        }
    )

at_cost_results = pd.DataFrame(at_cost_results)

# %%
g = sns.lineplot(
    data = at_cost_results,
    x='temperature',
    y='prob'
)

lower, upper = compute_confidence_interval(
    at_cost_results['n_success'],
    at_cost_results['n_failure']
)

g.fill_between(
    at_cost_results['temperature'],
    lower,
    upper,
    alpha=0.2
)

g.set_title(f'Probably of reaching goal @ {at_cost} mols vs. temperature in IDEATION step')
g.set_xlabel(f'Temperature')
g.set_ylabel(f'Probability of Reaching Goal')
g.set_ylim([0, 1.1])
# Out:
# (0.0, 1.1)

# %% [markdown]
# Plotting expected costs.

# %%
g = sns.lineplot(
    data = df,
    x='temperature',
    y='cost',
    # hue='sigma',
    # errorbar='sd'
)

g.set_title(f'Expected cost of reaching goal vs. temperature in IDEATION step')
g.set_ylabel(f'Expected Cost of Reaching Goal')
g.set_xlabel(f'Temperature')
# Out:
# Text(0.5, 0, 'Temperature')
