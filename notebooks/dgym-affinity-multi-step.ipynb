# %%
# %reload_ext autoreload
# %autoreload 2

import rdkit
rdkit.Chem.Draw.IPythonConsole.ipython_maxProperties = -1

import dgym as dg

# load all data
path = '../../dgym-data'

deck = dg.MoleculeCollection.load(
    f'{path}/DSi-Poised_Library_annotated.sdf',
    reactant_names=['reagsmi1', 'reagsmi2', 'reagsmi3']
)

reactions = dg.ReactionCollection.from_json(
    path = f'{path}/All_Rxns_rxn_library.json',
    smarts_col = 'reaction_string',
    classes_col = 'functional_groups'
)

building_blocks = dg.datasets.disk_loader(f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630.sdf')
fingerprints = dg.datasets.fingerprints(f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630_atoms.fpb')

import torch
import pyarrow.parquet as pq
table = pq.read_table('../../dgym-data/sizes.parquet')[0]
sizes = torch.tensor(table.to_numpy())

# %% [markdown]
# Working on new docking oracles.

# %%
from dgym.envs.oracle import DockingOracle, NeuralOracle, NoisyOracle
from dgym.envs.utility import ClassicUtilityFunction

config = {
    'center_x': 44.294,
    'center_y': 28.123,
    'center_z': 2.617,
    'size_x': 22.5,
    'size_y': 22.5,
    'size_z': 22.5,
    'search_mode': 'balanced',
    'scoring': 'gnina',
    'seed': 5
}

# Create noiseless evaluators
docking_oracle = DockingOracle(
    'ADAM17 affinity',
    receptor_path=f'../../dgym-data/ADAM17.pdbqt',
    config=config
)

docking_utility = ClassicUtilityFunction(
    docking_oracle,
    ideal=(9.5, 11.5),
    acceptable=(7.125, 9.5)
)

# Create noisy evaluator
noisy_docking_oracle = NoisyOracle(
    docking_oracle,
    sigma=0.5
)

noisy_docking_utility = ClassicUtilityFunction(
    noisy_docking_oracle,
    ideal=(8.5, 9.5),
    acceptable=(7.125, 9.5)
)

# %% [markdown]
# Run experiment.

# %%
from dgym.molecule import Molecule
from dgym.envs.designer import Designer, Generator
from dgym.envs.drug_env import DrugEnv
from dgym.agents import MultiStepDrugAgent
from dgym.agents.exploration import EpsilonGreedy
from dgym.experiment import Experiment

designer = Designer(
    Generator(building_blocks, fingerprints, sizes),
    reactions,
    cache = True
)

drug_env = DrugEnv(
    designer,
    library = deck[10:15].update_annotations(),
    assays = [docking_utility.oracle.reset_cache()],
    budget = 400,
    utility_function = docking_utility,
)

sequence = [
    {'name': 'ideate', 'parameters': {'temperature': 0.1, 'size': 10, 'strict': False}},
    {'name': 'ideate', 'parameters': {'temperature': 0.1, 'size': 10, 'strict': True}},
    {'name': 'ADAM17 affinity'},
]

drug_agent = MultiStepDrugAgent(
    num_steps = 2,
    designer = designer,
    sequence = sequence,
    utility_function = noisy_docking_utility,
    exploration_strategy = EpsilonGreedy(epsilon = 0.0),
    branch_factor = 1
)

experiment = Experiment(drug_agent, drug_env)

print(experiment.drug_env.assays['ADAM17 affinity'](experiment.drug_env.library)[0])
result = experiment.run(1, progress=True)
# Out:
# 5.672063125462473
#   0%|                                                                                             | 0/1 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/400 [00:00<?, ?it/s]
# 5.672063125462473
#   4%|███▎                                                                              | 16/400 [00:11<04:29,  1.43it/s]
#
#
#
# 542it [19:04,  2.11s/it]                                                               | 26/400 [00:40<10:54,  1.75s/it]
# 1658it [19:36,  1.41it/s]
# 6.78076436331222
#   9%|███████▍                                                                          | 36/400 [02:34<34:17,  5.65s/it]
# 6.78076436331222
#  12%|█████████▍                                                                        | 46/400 [03:48<37:00,  6.27s/it]
# 6.78076436331222
#   0%|                                                                                             | 0/1 [04:15<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 40
#      37 experiment = Experiment(drug_agent, drug_env)
#      39 print(experiment.drug_env.assays['ADAM17 affinity'](experiment.drug_env.library)[0])
# ---> 40 result = experiment.run(1, progress=True)
#
# File ~/dev/chodera/dgym/dgym/experiment.py:23, in Experiment.run(self, num_trials, progress, **kwargs)
#      21 print(self.drug_env.assays['ADAM17 affinity'](observations)[0])
#      22 while True:
# ---> 23     action = self.drug_agent.act(observations)
#      24     observations, _, terminated, truncated, _ = self.drug_env.step(action)
#      26     try:
#
# File ~/dev/chodera/dgym/dgym/agents/drug_agent.py:59, in DrugAgent.act(self, observations, mask)
#      45     indices = list(range(len(observations)))
#      47     # # Only latest-cycle
#      48     # current_cycle = max(o.design_cycle for o in observations)
#      49
#    (...)
#      57
#      58 # Extract action utility from the policy
# ---> 59 utility = self.policy(observations)
#      61 # Apply negative bias to utility of masked actions (True = valid)
#      62 if mask:
#
# File ~/dev/chodera/dgym/dgym/agents/drug_agent.py:144, in MultiStepDrugAgent.policy(self, observations)
#     141     leaves_ = self.multi_step_lookahead(observation)
#     142     leaves.extend(leaves_)
# --> 144 scores = self.utility_function(leaves).reshape(len(observations), -1)
#     145 aggregated_scores = self.agg_func(scores, axis=1)
#     147 return aggregated_scores
#
# File ~/dev/chodera/dgym/dgym/envs/utility.py:19, in UtilityFunction.__call__(self, input)
#      16 def __call__(self, input):
#      18     if isinstance(input[0], Molecule):
# ---> 19         input = self.oracle(input)
#      21     return self.score(input)
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:30, in Oracle.__call__(self, molecules, **kwargs)
#      29 def __call__(self, molecules: Union[MoleculeCollection, list], **kwargs):
# ---> 30     return self.get_predictions(molecules, **kwargs)
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:91, in NoisyOracle.get_predictions(self, molecules, **kwargs)
#      80 """
#      81 Get predictions from the oracle and add Gaussian noise.
#      82
#    (...)
#      88 - List[float]: The noisy predictions for the given molecules.
#      89 """
#      90 # Utilize the wrapped oracle to get predictions
# ---> 91 predictions = self.oracle.get_predictions(molecules, **kwargs)
#      93 # Add Gaussian noise to each prediction
#      94 noisy_predictions = [p + np.random.normal(0, self.sigma) for p in predictions]
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:50, in Oracle.get_predictions(self, molecules, **kwargs)
#      46 not_in_cache = lambda m: m.smiles not in self.cache
#      47 if uncached_molecules := set(filter(not_in_cache, molecules)):
#      48
#      49     # make predictions
# ---> 50     smiles, scores = self.predict(uncached_molecules, **kwargs)
#      52     # cache results
#      53     self.cache.update(zip(smiles, scores))
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:195, in DockingOracle.predict(self, molecules, path, units)
#     192 command = self._prepare_command(self.config, directory)
#     194 # run docking
# --> 195 resp = self._dock(command)
#     197 # gather results
#     198 smiles, scores = self._gather_results(directory)
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:257, in DockingOracle._dock(self, command)
#     255 def _dock(self, command: str):
#     256     import subprocess
# --> 257     return subprocess.run(
#     258         command,
#     259         shell=True,
#     260         stdout=subprocess.PIPE,
#     261         stderr=subprocess.PIPE,
#     262         encoding='utf-8'
#     263     )
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:2108, in Popen._communicate(self, input, endtime, orig_timeout)
#    2101     self._check_timeout(endtime, orig_timeout,
#    2102                         stdout, stderr,
#    2103                         skip_check_and_raise=True)
#    2104     raise RuntimeError(  # Impossible :)
#    2105         '_check_timeout(..., skip_check_and_raise=True) '
#    2106         'failed to raise TimeoutExpired.')
# -> 2108 ready = selector.select(timeout)
#    2109 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2111 # XXX Rewrite these to use non-blocking I/O on the file
#    2112 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/envs/chodera/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

scores = experiment.drug_agent.utility_function.oracle(experiment.drug_env.library)
design_cycles = experiment.drug_env.library.annotations['timestep'].fillna(0).astype(int)

df = pd.DataFrame({'score': scores, 'cycle': design_cycles})

# Ensure the DataFrame is sorted by time_step, then score
df = df.sort_values(by=['cycle', 'score'])

# Calculate the empirical CDF for each time step
df['cdf'] = (
    1 -
    df
    .groupby('cycle')['score']
    .transform(lambda x: np.arange(1, len(x) + 1) / len(x))
)

# Plot
g = sns.lineplot(
    data=df,
    x='score',
    y='cdf',
    hue='cycle',
    marker='o',
    palette='viridis_r'
)

plt.xlabel('pIC50')
plt.ylabel('Cumulative probability')
plt.title(f'Empirical CDF for Across Design Cycles')
g.legend(title='Week')

# %%
import seaborn as sns
import pandas as pd

scores = experiment.drug_agent.utility_function.oracle(experiment.drug_env.library)
design_cycles = experiment.drug_env.library.annotations['timestep'].fillna(0).astype(int)

sns.displot(
    data = pd.DataFrame({'scores': scores, 'design cycle': design_cycles}),
    x = 'scores',
    hue = 'design cycle',
    palette='viridis',
    kind='kde'
)
# Out:
# /home/mrr/miniconda3/envs/chodera/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd
from dgym.molecule import Molecule
from dgym.envs.designer import Designer, Generator
from dgym.envs.drug_env import DrugEnv
from dgym.agents import SequentialDrugAgent
from dgym.agents.exploration import EpsilonGreedy

results = []
sigmas = [0.0, 1e-1, 2e-1]

for sigma in tqdm(sigmas):
    
    noisy_docking_utility.oracle.sigma = sigma
    
    drug_env = DrugEnv(
        designer,
        library = dg.MoleculeCollection([best_molecules[-80]]).update_annotations(),
        assays = [docking_oracle],
        budget = 80,
        utility_function = docking_utility,
    )

    drug_agent = SequentialDrugAgent(
        sequence = sequence,
        utility_function = noisy_docking_utility,
        exploration_strategy = EpsilonGreedy(epsilon = 0.0),
        branch_factor = 2
    )

    experiment = Experiment(drug_agent, drug_env)
    result = experiment.run(2, sigma=sigma)
    results.extend(result)

df = pd.DataFrame(results)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 5.6168341108962645
# 5.6168341108962645
# 5.6168341108962645
# 6.1340211808450125
# 6.1340211808450125
# 6.1340211808450125
# 6.446015649866715
# 6.446015649866715
# 6.446015649866715
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 31
#      23     drug_agent = SequentialDrugAgent(
#      24         sequence = sequence,
#      25         utility_function = noisy_docking_utility,
#      26         exploration_strategy = EpsilonGreedy(epsilon = 0.0),
#      27         branch_factor = 2
#      28     )
#      30     experiment = Experiment(drug_agent, drug_env)
# ---> 31     result = experiment.run(2, sigma=sigma)
#      32     results.extend(result)
#      34 df = pd.DataFrame(results)
#
# Cell In[32], line 21, in Experiment.run(self, num_trials, progress, **kwargs)
#      18     pbar = tqdm(total = drug_env.budget)
#      20 while True:
# ---> 21     action = drug_agent.act(observations)
#      22     observations, _, terminated, truncated, _ = drug_env.step(action)
#      23     try:
#
# File ~/dev/chodera/dgym/dgym/agents/drug_agent.py:59, in DrugAgent.act(self, observations, mask)
#      45     indices = list(range(len(observations)))
#      47     # # Only latest-cycle
#      48     # current_cycle = max(o.design_cycle for o in observations)
#      49
#    (...)
#      57
#      58 # Extract action utility from the policy
# ---> 59 utility = self.policy(observations)
#      61 # Apply negative bias to utility of masked actions (True = valid)
#      62 if mask:
#
# File ~/dev/chodera/dgym/dgym/agents/drug_agent.py:104, in SequentialDrugAgent.policy(self, observations)
#     101 """
#     102 """
#     103 # convert scores to utility
# --> 104 return self.utility_function(observations)
#
# File ~/dev/chodera/dgym/dgym/envs/utility.py:16, in UtilityFunction.__call__(self, molecules)
#      15 def __call__(self, molecules):
# ---> 16     return self.score(self.oracle(molecules))
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:30, in Oracle.__call__(self, molecules, **kwargs)
#      29 def __call__(self, molecules: Union[MoleculeCollection, list], **kwargs):
# ---> 30     return self.get_predictions(molecules, **kwargs)
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:91, in NoisyOracle.get_predictions(self, molecules, **kwargs)
#      80 """
#      81 Get predictions from the oracle and add Gaussian noise.
#      82
#    (...)
#      88 - List[float]: The noisy predictions for the given molecules.
#      89 """
#      90 # Utilize the wrapped oracle to get predictions
# ---> 91 predictions = self.oracle.get_predictions(molecules, **kwargs)
#      93 # Add Gaussian noise to each prediction
#      94 noisy_predictions = [p + np.random.normal(0, self.sigma) for p in predictions]
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:50, in Oracle.get_predictions(self, molecules, **kwargs)
#      46 not_in_cache = lambda m: m.smiles not in self.cache
#      47 if uncached_molecules := set(filter(not_in_cache, molecules)):
#      48
#      49     # make predictions
# ---> 50     smiles, scores = self.predict(uncached_molecules, **kwargs)
#      52     # cache results
#      53     self.cache.update(zip(smiles, scores))
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:195, in DockingOracle.predict(self, molecules, path, units)
#     192 command = self._prepare_command(self.config, directory)
#     194 # run docking
# --> 195 resp = self._dock(command)
#     197 # gather results
#     198 smiles, scores = self._gather_results(directory)
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:257, in DockingOracle._dock(self, command)
#     255 def _dock(self, command: str):
#     256     import subprocess
# --> 257     return subprocess.run(
#     258         command,
#     259         shell=True,
#     260         stdout=subprocess.PIPE,
#     261         stderr=subprocess.PIPE,
#     262         encoding='utf-8'
#     263     )
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:2108, in Popen._communicate(self, input, endtime, orig_timeout)
#    2101     self._check_timeout(endtime, orig_timeout,
#    2102                         stdout, stderr,
#    2103                         skip_check_and_raise=True)
#    2104     raise RuntimeError(  # Impossible :)
#    2105         '_check_timeout(..., skip_check_and_raise=True) '
#    2106         'failed to raise TimeoutExpired.')
# -> 2108 ready = selector.select(timeout)
#    2109 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2111 # XXX Rewrite these to use non-blocking I/O on the file
#    2112 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/envs/chodera/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
import pandas as pd

def ecdf(costs):
    costs_sorted = np.sort(costs)
    probs = 1. * np.arange(1, len(costs) + 1) / len(costs)

    costs_sorted = [0.0, *costs_sorted]
    probs = [0.0, *probs]
    
    return costs_sorted, probs

data = pd.DataFrame()
noises = sigmas
for noise in noises:
    raw_costs = [r['cost'] for r in df.to_dict('records') if r['sigma'] == noise]
    cost, prob = ecdf(raw_costs)
    temp = pd.DataFrame({'cost': cost, 'prob': prob, 'noise': noise})
    data = pd.concat([data, temp])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
g = sns.lineplot(
    data,
    x='cost',
    y='prob',
    hue='noise',
    palette='colorblind',
)

g.set_title('Escalating noise in SELECTION step')
g.set_xlabel('# Molecules')
g.set_ylabel('Probability of Reaching Goal')
g.set_ylim([0, 1.1])
g.set_xlim(0, 400)

plt.gcf().set_dpi(150)
plt.show()
