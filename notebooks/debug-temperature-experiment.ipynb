# %% [markdown]
# # Debugging why the temperature experiment is crashing

# %%
import uuid
import argparse
import dgym as dg
import pandas as pd

def get_data(path):

    deck = dg.MoleculeCollection.load(
        f'{path}/DSi-Poised_Library_annotated.sdf',
        reactant_names=['reagsmi1', 'reagsmi2', 'reagsmi3']
    )

    reactions = dg.ReactionCollection.from_json(
        path = f'{path}/All_Rxns_rxn_library_sorted.json',
        smarts_col = 'reaction_string',
        classes_col = 'functional_groups'
    )

    building_blocks = dg.datasets.disk_loader(
        f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630.sdf')
    fingerprints = dg.datasets.fingerprints(
        f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630_atoms.fpb')

    import torch
    import pyarrow.parquet as pq
    table = pq.read_table(f'{path}/sizes.parquet')[0]
    sizes = torch.tensor(table.to_numpy())

    return deck, reactions, building_blocks, fingerprints, sizes

def get_initial_library(deck, designer):
    
    # select first molecule
    import random
    def _select_molecule(deck):
        initial_index = random.randint(0, len(deck) - 1)
        initial_molecule = deck[initial_index]
        if len(initial_molecule.reactants) == 2 \
            and designer.match_reactions(initial_molecule):
            return initial_molecule
        else:
            return _select_molecule(deck)

    initial_molecules = [_select_molecule(deck) for _ in range(5)]
    library = dg.MoleculeCollection(initial_molecules).update_annotations()
    
    return library
    
def get_docking_config(path: str, target_index: int):
    
    import os

    dockstring_dir = f'{path}/dockstring_targets/'
    files = os.listdir(dockstring_dir)
    configs = sorted([f for f in files if 'conf' in f])
    targets = sorted([f for f in files if 'target' in f])

    with open(dockstring_dir + configs[target_index], 'r') as f:
        config_ = f.readlines()
        config_ = [c.replace('\n', '') for c in config_]
        config_ = [c.split(' = ') for c in config_ if c]
        config_ = {c[0]: float(c[1]) for c in config_}

    target_file = targets[target_index]
    target = target_file.split('_')[0]
    
    config = {
        'search_mode': 'detailed',
        'scoring': 'vina',
        'seed': 5,
        'size_x': 22.5,
        'size_y': 22.5,
        'size_z': 22.5,
        **config_
    }
    
    return target, config

def get_oracles(path: str, target_index: int):

    from dgym.envs.oracle import \
        DockingOracle, CatBoostOracle, RDKitOracle, NoisyOracle
    from dgym.envs.utility import ClassicUtilityFunction
    
    target, config = get_docking_config(path, target_index)

    pIC50_oracle = DockingOracle(
        f'{target} pIC50',
        receptor_path=f'{path}/dockstring_targets/{target}_target.pdbqt',
        config=config
    )
    log_P_oracle = RDKitOracle('Log P', descriptor='MolLogP')
    log_S_oracle = CatBoostOracle(
        'Log S', path='../dgym/envs/models/aqsolcb.model')
    
    return pIC50_oracle, log_P_oracle, log_S_oracle

def get_multiple_utility_functions(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle,
    sigma=1.0
):
    from dgym.envs.utility import (
        ClassicUtilityFunction, MultipleUtilityFunction
    )

    # Define utility functions
    pIC50_utility = ClassicUtilityFunction(
        pIC50_oracle, ideal=(9, 13), acceptable=(8, 13))
    log_P_utility = ClassicUtilityFunction(
        log_P_oracle, ideal=(0.5, 1.85), acceptable=(-0.5, 3.5))
    log_S_utility = ClassicUtilityFunction(
        log_S_oracle, ideal=(-3, 1), acceptable=(-4, 1))

    # Assemble assays and surrogate models
    assays = [
        pIC50_oracle,
        log_P_oracle,
        log_S_oracle,
        pIC50_oracle.surrogate(sigma=sigma),
        log_P_oracle.surrogate(sigma=sigma),
        log_S_oracle.surrogate(sigma=sigma),
    ]

    # Environment tolerates acceptable ADMET
    from copy import deepcopy
    utility_agent = MultipleUtilityFunction(
        utility_functions = [pIC50_utility, log_P_utility, log_S_utility],
        weights = [0.8, 0.1, 0.1]
    )
    utility_env = deepcopy(utility_agent)
    utility_env.utility_functions[1].ideal = utility_env.utility_functions[1].acceptable
    utility_env.utility_functions[2].ideal = utility_env.utility_functions[2].acceptable
    
    return assays, utility_agent, utility_env

def get_agent_sequence(temperature: float):
    """
    Make the sequence for the DrugAgent.
    """

    design_grow = {'name': 'design', 'batch_size': 384, 'parameters': {'strategy': 'grow', 'size': 5}}
    design_replace = {
        'name': 'design',
        'batch_size': 384,
        'parameters': {'strategy': 'replace', 'size': 5, 'temperature': temperature, 'limit': 10}
    }
    score = {
        'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'],
        'batch_size': 384 * 5,
        'parameters': {'batch_size': 40, 'parallel': False},
    }
    make = {'name': 'make', 'batch_size': 384}
    test = {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'batch_size': 384}
    design_and_score = [design_replace, score]

    return [*(design_and_score * 1), design_grow, score, make, test]

# %%
# Run experiment
path = '../../dgym-data'

# Load all data
(
    deck,
    reactions,
    building_blocks,
    fingerprints,
    sizes
) = get_data(path)

# Get starting library
from dgym.envs.designer import Designer, Generator
designer = Designer(
    Generator(building_blocks, fingerprints, sizes), reactions, cache = True)
library = get_initial_library(deck, designer)

# Get Oracles
(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle
) = get_oracles(
    path=path,
    target_index=0
)

# Create multiple utility functions
(
    assays,
    utility_agent,
    utility_env
) = get_multiple_utility_functions(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle,
)

# Create DrugEnv
from dgym.envs import DrugEnv
drug_env = DrugEnv(
    designer = designer,
    library = library,
    assays = assays,
    utility_function = utility_env
)

# Create DrugAgent
temperature = 0.1

from dgym.agents import SequentialDrugAgent
from dgym.agents.exploration import EpsilonGreedy
sequence = get_agent_sequence(temperature = temperature)
drug_agent = SequentialDrugAgent(
    sequence = sequence,
    exploration_strategy = EpsilonGreedy(epsilon=0.2),
    utility_function = utility_agent
)

# Create and run Experiment
# file_path = f'./out/selection_temperature_{temperature}_{uuid.uuid4()}.json'

from dgym.experiment import Experiment
experiment = Experiment(
    drug_agent=drug_agent, drug_env=drug_env)
result = experiment.run(temperature=temperature)[0]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Memory before action: Memory Usage: 12.10 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.1, 'limit': 10}, 'molecules': [0, 1, 2, 3, 4]}
# Memory after action: Memory Usage: 12.11 GB
# -inf
# Memory before action: Memory Usage: 12.11 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40, 'parallel': False}, 'molecules': [5, 6, 7, 8, 9, 26, 10, 20, 11, 12, 13, 14, 27, 28, 15, 16, 17, 18, 19, 24, 21, 22, 23, 25, 29]}
# {'batch_size': 40, 'parallel': False}
# {'batch_size': 40, 'parallel': False}
# {'batch_size': 40, 'parallel': False}
# Memory after action: Memory Usage: 12.11 GB
# -inf
# Memory before action: Memory Usage: 12.11 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'grow', 'size': 5}, 'molecules': [14, 25, 12, 13, 24, 26, 27, 7, 21, 20, 8, 28, 19, 22, 15, 6, 11, 10, 17, 29, 9, 18, 23, 5, 16]}
# Memory after action: Memory Usage: 12.12 GB
# -inf
# Memory before action: Memory Usage: 12.12 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40, 'parallel': False}, 'molecules': [30, 31, 32, 33, 34, 38, 35, 36, 37, 105, 39, 40, 41, 75, 42, 43, 44, 45, 46, 47, 48, 49, 130, 95, 50, 51, 52, 53, 54, 109, 55, 56, 57, 58, 59, 60, 61, 134, 62, 106, 63, 64, 65, 66, 67, 68, 69, 98, 70, 71, 152, 72, 73, 74, 76, 77, 78, 79, 116, 80, 81, 82, 83, 84, 85, 86, 120, 87, 136, 88, 89, 90, 147, 91, 92, 151, 93, 94, 96, 97, 146, 99, 104, 100, 101, 102, 103, 107, 145, 108, 110, 124, 111, 112, 113, 119, 114, 126, 115, 117, 153, 118, 141, 125, 121, 122, 123, 127, 154, 128, 133, 129, 131, 132, 135, 137, 138, 139, 140, 142, 143, 144, 148, 149, 150]}
# {'batch_size': 40, 'parallel': False}
# {'batch_size': 40, 'parallel': False}
# {'batch_size': 40, 'parallel': False}
# Memory after action: Memory Usage: 12.12 GB
# -inf
# Memory before action: Memory Usage: 12.12 GB
# Created action
# {'name': 'make', 'parameters': {}, 'molecules': [94, 25, 117, 103, 91, 12, 60, 121, 148, 98, 63, 152, 127, 61, 151, 24, 75, 128, 154, 7, 122, 31, 87, 71, 90, 129, 27, 96, 104, 11, 124, 14, 13, 115, 88, 126, 34, 153, 73, 133, 28, 97, 147, 78, 64, 72, 85, 32, 22, 20, 146, 93, 74, 123, 70, 132, 8, 135, 54, 40, 19, 114, 53, 15, 38, 119, 137, 44, 134, 51, 112, 143, 58, 145, 118, 57, 41, 92, 6, 84, 47, 100, 17, 30, 141, 56, 39, 45, 95, 49, 149, 33, 21, 108, 105, 18, 102, 59, 80, 52, 144, 142, 43, 77, 83, 89, 46, 66, 106, 111, 42, 37, 107, 10, 23, 136, 50, 86, 29, 109, 65, 110, 116, 16, 68, 9, 130, 5, 138, 81, 101, 62, 131, 35, 79, 69, 26, 139, 150, 99, 36, 48, 140, 76, 55, 82, 67, 125, 113, 120]}
# Memory after action: Memory Usage: 12.12 GB
# -inf
# Memory before action: Memory Usage: 12.12 GB
# Created action
# {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'parameters': {}, 'molecules': [94, 25, 117, 103, 91, 12, 60, 121, 148, 98, 63, 152, 138, 85, 127, 61, 151, 24, 75, 128, 154, 124, 7, 122, 31, 87, 71, 90, 129, 27, 104, 14, 143, 13, 115, 126, 34, 73, 133, 28, 147, 78, 64, 72, 32, 22, 20, 140, 93, 74, 123, 70, 132, 8, 120, 135, 54, 19, 136, 81, 114, 15, 38, 119, 137, 59, 153, 51, 53, 112, 58, 145, 67, 118, 41, 92, 37, 6, 84, 100, 17, 30, 141, 125, 56, 39, 49, 149, 86, 33, 21, 57, 108, 44, 105, 95, 18, 102, 80, 89, 52, 35, 144, 142, 134, 43, 77, 11, 83, 66, 111, 42, 47, 10, 16, 50, 110, 45, 116, 79, 40, 29, 68, 9, 130, 65, 46, 23, 62, 131, 5, 26, 69, 101, 146, 109, 139, 76, 106, 97, 150, 36, 55, 48, 107, 99, 82, 113, 96, 88]}
# {}
# {}
# {}
# Memory after action: Memory Usage: 12.12 GB
# -0.24055775378584385
# Memory before action: Memory Usage: 12.12 GB
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.1, 'limit': 10}, 'molecules': [14, 24, 18, 37, 91, 153, 60, 25, 152, 89, 77, 149, 17, 71, 154, 127, 10, 32, 139, 92, 53, 128, 103, 102, 72, 90, 11, 104, 84, 22, 9, 98, 101, 132, 93, 113, 133, 34, 54, 121, 129, 110, 41, 31, 83, 143, 76, 33, 61, 66, 70, 45, 95, 141, 75, 20, 115, 100, 78, 51, 38, 63, 23, 97, 62, 114, 50, 42, 108, 99, 85, 68, 118, 124, 39, 16, 79, 131, 94, 19, 151, 81, 122, 112, 142, 55, 120, 56, 13, 134, 12, 125, 88, 87, 150, 86, 59, 47, 119, 123, 130, 126, 137, 73, 80, 15, 145, 82, 105, 27, 35, 116, 7, 36, 96, 74, 43, 107, 21, 30, 117, 109, 5, 58, 106, 147, 52, 64, 67, 140, 6, 146, 69, 8, 40, 144, 136, 65, 28, 138, 57, 148, 29, 135, 26, 44, 49, 48, 111, 46]}
# Memory after action: Memory Usage: 12.16 GB
# -0.24055775378584385
# Memory before action: Memory Usage: 12.16 GB
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 40, 'parallel': False}, 'molecules': [155, 156, 684, 157, 158, 159, 397, 160, 161, 854, 162, 163, 164, 165, 565, 735, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175,