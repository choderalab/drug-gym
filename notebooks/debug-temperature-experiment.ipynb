# %% [markdown]
# # Debugging why the temperature experiment is crashing

# %%
import uuid
import argparse
import dgym as dg
import pandas as pd

def get_data(path):

    deck = dg.MoleculeCollection.load(
        f'{path}/DSi-Poised_Library_annotated.sdf',
        reactant_names=['reagsmi1', 'reagsmi2', 'reagsmi3']
    )

    reactions = dg.ReactionCollection.from_json(
        path = f'{path}/All_Rxns_rxn_library.json',
        smarts_col = 'reaction_string',
        classes_col = 'functional_groups'
    )

    building_blocks = dg.datasets.disk_loader(
        f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630.sdf')
    fingerprints = dg.datasets.fingerprints(
        f'{path}/Enamine_Building_Blocks_Stock_262336cmpd_20230630_atoms.fpb')

    import torch
    import pyarrow.parquet as pq
    table = pq.read_table(f'{path}/sizes.parquet')[0]
    sizes = torch.tensor(table.to_numpy())

    return deck, reactions, building_blocks, fingerprints, sizes

def get_initial_library(deck, designer):
    
    # select first molecule
    import random
    def _select_molecule(deck):
        initial_index = random.randint(0, len(deck) - 1)
        initial_molecule = deck[initial_index]
        if len(initial_molecule.reactants) == 2 \
            and designer.match_reactions(initial_molecule):
            return initial_molecule
        else:
            return _select_molecule(deck)

    initial_molecules = [_select_molecule(deck) for _ in range(5)]
    library = dg.MoleculeCollection(initial_molecules).update_annotations()
    
    return library
    
def get_docking_config(path: str, target_index: int):
    
    import os

    dockstring_dir = f'{path}/dockstring_targets/'
    files = os.listdir(dockstring_dir)
    configs = sorted([f for f in files if 'conf' in f])
    targets = sorted([f for f in files if 'target' in f])

    with open(dockstring_dir + configs[target_index], 'r') as f:
        config_ = f.readlines()
        config_ = [c.replace('\n', '') for c in config_]
        config_ = [c.split(' = ') for c in config_ if c]
        config_ = {c[0]: float(c[1]) for c in config_}

    target_file = targets[target_index]
    target = target_file.split('_')[0]
    
    config = {
        'search_mode': 'detailed',
        'scoring': 'vina',
        'seed': 5,
        'size_x': 22.5,
        'size_y': 22.5,
        'size_z': 22.5,
        **config_
    }
    
    return target, config

def get_oracles(path: str, target_index: int):

    from dgym.envs.oracle import \
        DockingOracle, CatBoostOracle, RDKitOracle, NoisyOracle
    from dgym.envs.utility import ClassicUtilityFunction
    
    target, config = get_docking_config(path, target_index)

    pIC50_oracle = DockingOracle(
        f'{target} pIC50',
        receptor_path=f'{path}/dockstring_targets/{target}_target.pdbqt',
        config=config
    )
    log_P_oracle = RDKitOracle('Log P', descriptor='MolLogP')
    log_S_oracle = CatBoostOracle(
        'Log S', path='../dgym/envs/models/aqsolcb.model')
    
    return pIC50_oracle, log_P_oracle, log_S_oracle

def get_multiple_utility_functions(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle,
    sigma=1.0
):
    from dgym.envs.utility import (
        ClassicUtilityFunction, MultipleUtilityFunction
    )

    # Define utility functions
    pIC50_utility = ClassicUtilityFunction(
        pIC50_oracle, ideal=(9, 13), acceptable=(8, 13))
    log_P_utility = ClassicUtilityFunction(
        log_P_oracle, ideal=(0.5, 1.85), acceptable=(-0.5, 3.5))
    log_S_utility = ClassicUtilityFunction(
        log_S_oracle, ideal=(-3, 1), acceptable=(-4, 1))

    # Assemble assays and surrogate models
    assays = [
        pIC50_oracle,
        log_P_oracle,
        log_S_oracle,
        pIC50_oracle.surrogate(sigma=sigma),
        log_P_oracle.surrogate(sigma=sigma),
        log_S_oracle.surrogate(sigma=sigma),
    ]

    # Environment tolerates acceptable ADMET
    from copy import deepcopy
    utility_agent = MultipleUtilityFunction(
        utility_functions = [pIC50_utility, log_P_utility, log_S_utility],
        weights = [0.8, 0.1, 0.1]
    )
    utility_env = deepcopy(utility_agent)
    utility_env.utility_functions[1].ideal = utility_env.utility_functions[1].acceptable
    utility_env.utility_functions[2].ideal = utility_env.utility_functions[2].acceptable
    
    return assays, utility_agent, utility_env

def get_agent_sequence(temperature: float):
    """
    Make the sequence for the DrugAgent.
    """

    design_grow = {'name': 'design', 'batch_size': 24, 'parameters': {'strategy': 'grow', 'size': 5}}
    design_replace = {
        'name': 'design',
        'batch_size': 24,
        'parameters': {'strategy': 'replace', 'size': 5, 'temperature': temperature, 'limit': 10}
    }
    score = {
        'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'],
        'batch_size': 24 * 5,
        'parameters': {'batch_size': 24, 'parallel': False},
    }
    make = {'name': 'make', 'batch_size': 24}
    test = {'name': ['ABL1 pIC50', 'Log S', 'Log P'], 'batch_size': 24}
    design_and_score = [design_replace, score]

    return [*(design_and_score * 1), design_grow, score, make, test]

# %%
# Run experiment
path = '../../dgym-data'

# Load all data
(
    deck,
    reactions,
    building_blocks,
    fingerprints,
    sizes
) = get_data(path)

# Get starting library
from dgym.envs.designer import Designer, Generator
designer = Designer(
    Generator(building_blocks, fingerprints, sizes), reactions, cache = True)
library = get_initial_library(deck, designer)

# Get Oracles
(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle
) = get_oracles(
    path=path,
    target_index=0
)

# Create multiple utility functions
(
    assays,
    utility_agent,
    utility_env
) = get_multiple_utility_functions(
    pIC50_oracle,
    log_P_oracle,
    log_S_oracle,
)

# Create DrugEnv
from dgym.envs import DrugEnv
drug_env = DrugEnv(
    designer = designer,
    library = library,
    assays = assays,
    utility_function = utility_env
)

# Create DrugAgent
temperature = 0.5

from dgym.agents import SequentialDrugAgent
from dgym.agents.exploration import EpsilonGreedy
sequence = get_agent_sequence(temperature = temperature)
drug_agent = SequentialDrugAgent(
    sequence = sequence,
    exploration_strategy = EpsilonGreedy(epsilon=0.2),
    utility_function = utility_agent
)

# Create and run Experiment
# file_path = f'./out/selection_temperature_{temperature}_{uuid.uuid4()}.json'

from dgym.experiment import Experiment
experiment = Experiment(
    drug_agent=drug_agent, drug_env=drug_env)
result = experiment.run(temperature=temperature)[0]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Created action
# {'name': 'design', 'parameters': {'strategy': 'replace', 'size': 5, 'temperature': 0.5, 'limit': 10}, 'molecules': [0, 1, 2, 3, 4]}
# -inf
# Created action
# {'name': ['Noisy ABL1 pIC50', 'Noisy Log S', 'Noisy Log P'], 'parameters': {'batch_size': 24, 'parallel': False}, 'molecules': [5, 6, 7, 8, 17, 9, 10, 11, 20, 12, 13, 14, 15, 16, 18, 19, 21, 24, 22, 23, 25, 26, 27, 28, 29]}
# {'batch_size': 24, 'parallel': False}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 67
#      64 from dgym.experiment import Experiment
#      65 experiment = Experiment(
#      66     drug_agent=drug_agent, drug_env=drug_env)
# ---> 67 result = experiment.run(temperature=temperature)[0]
#
# File ~/dev/chodera/dgym/dgym/experiment.py:42, in Experiment.run(self, num_trials, progress, out, **kwargs)
#      40 print('Created action', flush=True)
#      41 print(action, flush=True)
# ---> 42 observations, _, terminated, truncated, _ = self.drug_env.step(action)
#      44 # Parse result
#      45 result = self.get_result(trial, out=out, **kwargs)
#
# File ~/dev/chodera/dgym/dgym/envs/drug_env.py:140, in DrugEnv.step(self, action)
#     103 """
#     104 Run one timestep of the environment's dynamics using the agent actions.
#     105 When the end of an episode is reached (terminated or truncated),
#    (...)
#     137
#     138 """
#     139 # Perform action
# --> 140 self.library = self.perform_action(action)
#     142 # Update valid actions
#     143 self.valid_actions[:len(self.library)] = True
#
# File ~/dev/chodera/dgym/dgym/envs/drug_env.py:171, in DrugEnv.perform_action(self, action)
#     163 # Perform action
#     164 for action_name in dg.utils.normalize_list(action_name):
#     165     match action_name:
#     166         case 'design':
#     167             self.library += self.design(molecules, **parameters)
#     168         case 'make':
#     169             self.make(molecules)
#     170         case _ as test:
# --> 171             self.test(molecules, test, **parameters)
#     173 return self.library.reset_index()
#
# File ~/dev/chodera/dgym/dgym/envs/drug_env.py:222, in DrugEnv.test(self, molecules, assay_name, **params)
#     220 # Perform inference
#     221 print(params, flush=True)
# --> 222 results = assay(molecules, **params)
#     224 # Update library annotations for molecules measured
#     225 for molecule, result in zip(molecules, results):
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:43, in Oracle.__call__(self, molecules, **kwargs)
#      40 molecules = MoleculeCollection(molecules)
#      42 # Make predictions
# ---> 43 predictions = self.get_predictions(molecules, **kwargs)
#      45 return predictions if return_list else predictions[0]
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:134, in NoisyOracle.get_predictions(self, molecules, **kwargs)
#     123 """
#     124 Get predictions from the oracle and add Gaussian noise.
#     125
#    (...)
#     131 - List[float]: The noisy predictions for the given molecules.
#     132 """
#     133 # Utilize the wrapped oracle to get predictions
# --> 134 predictions = self.oracle.get_predictions(molecules, **kwargs)
#     136 # Add Gaussian noise to each prediction
#     137 noisy_predictions = [p + np.random.normal(0, self.sigma) for p in predictions]
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:67, in Oracle.get_predictions(self, molecules, use_cache, **kwargs)
#      60 def get_predictions(
#      61     self,
#      62     molecules: Union[MoleculeCollection, list],
#      63     use_cache: bool = True,
#      64     **kwargs
#      65 ):
#      66     if use_cache:
# ---> 67         return self._get_predictions(molecules, **kwargs)
#      68     else:
#      69         with self.suspend_cache():
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:86, in Oracle._get_predictions(self, molecules, batch_size, **kwargs)
#      84 if uncached_molecules := molecules.filter(uncached):
#      85     for batch in uncached_molecules.batch(batch_size):
# ---> 86         smiles, predictions = self.predict(batch, **kwargs)
#      87         self.cache.update(zip(smiles, predictions))
#      89 # Match input ordering
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:306, in DockingOracle.predict(self, molecules, path, units, **kwargs)
#     303 command = self._prepare_command(self.config, directory)
#     305 # run docking
# --> 306 resp = self._dock(command)
#     308 # gather results
#     309 smiles, scores = self._gather_results(directory)
#
# File ~/dev/chodera/dgym/dgym/envs/oracle.py:370, in DockingOracle._dock(self, command)
#     368 def _dock(self, command: str):
#     369     import subprocess
# --> 370     return subprocess.run(
#     371         command,
#     372         shell=True,
#     373         stdout=subprocess.PIPE,
#     374         stderr=subprocess.PIPE,
#     375         encoding='utf-8'
#     376     )
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/miniconda3/envs/chodera/lib/python3.11/subprocess.py:2108, in Popen._communicate(self, input, endtime, orig_timeout)
#    2101     self._check_timeout(endtime, orig_timeout,
#    2102                         stdout, stderr,
#    2103                         skip_check_and_raise=True)
#    2104     raise RuntimeError(  # Impossible :)
#    2105         '_check_timeout(..., skip_check_and_raise=True) '
#    2106         'failed to raise TimeoutExpired.')
# -> 2108 ready = selector.select(timeout)
#    2109 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2111 # XXX Rewrite these to use non-blocking I/O on the file
#    2112 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/envs/chodera/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
